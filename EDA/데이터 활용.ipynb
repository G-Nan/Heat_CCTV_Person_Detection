# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

sns.set_style('whitegrid')
colors = sns.color_palette("pastel")
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
labels1 = ['현역병 모집 실적', '현역병 입영 현황', '신분별 군 정원', '사관학교 입학 경쟁률', '병사 봉급 정보',
          'Armed forces personnel', 'Military expenditure']
sizes1 = [2, 1, 1, 1, 1, 1, 1]
colors1 = [
    '#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6', 
    '#c4e17f']
explode1 = (0.1, 0, 0, 0, 0, 0, 0)  # explode 1st slice

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('데이터별 분석에 사용된 빈도', fontsize = 18)

plt.show()

# %%
labels2 = ['국방부', '병무청', '외부 공공데이터', '개인 데이터']
sizes2 = [3, 2, 6, 1]
colors2 = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
explode2 = (0.1, 0.1, 0, 0)  # explode 1st slice

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('관리기관별 사용 데이터 빈도', fontsize = 18)

plt.show()

# %%
labels3 = ['AI_HUB', '대전광역시', '대전교통공사', 'Mendeley', 'Roboflow']
sizes3 = [3, 4, 6, 32, 48]
colors3 = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0']

explode3 = (0, 0, 0, 0, 0)  # explode 1st slice

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('학습에 사용된 데이터 비중', fontsize = 18)

plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

ax1.pie(sizes1, explode=explode1, labels=labels1, colors=colors1, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.set_title('데이터별 분석에 사용된 빈도', fontsize = 18)

ax2.pie(sizes2, explode=explode2, labels=labels2, colors=colors2, autopct='%1.1f%%', shadow=True, startangle=90)
ax2.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax2.set_title('관리기관별 사용 데이터 빈도', fontsize = 18)

ax3.pie(sizes3, explode=explode3, labels=labels3, colors=colors3, autopct='%1.1f%%', shadow=True, startangle=90)
ax3.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax3.set_title('학습에 사용된 데이터 비중', fontsize = 18)

plt.show()
